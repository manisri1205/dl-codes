# %%
import numpy as np
import keras
from keras.models import load_model
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping

import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train.reshape(60000,784)
x_test=x_test.reshape(10000,784)

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
y_train=y_train.astype('float32')
y_test=y_test.astype('float32')

x_train/=255
x_test/=255
num_classes=10
y_train=keras.utils.to_categorical(y_train,num_classes)
y_test=keras.utils.to_categorical(y_test,num_classes)
ncols=x_train.shape[1]
model2=Sequential()
model2.add(Dense(512,activation='relu',input_shape=(ncols,)))
model2.add(Dropout(0.2))
model2.add(Dense(512,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(num_classes,activation='softmax'))
model2.save('model_2.h5')
model2.compile(loss='categorical_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])
score2= model2.evaluate(x_test, y_test, verbose=0)
early_stopping_monitor=EarlyStopping(patience=3)


fit2=model2.fit(x_train,y_train,
                batch_size=128,
                epochs=20,
                callbacks=[early_stopping_monitor],
                verbose=1,
                validation_data=(x_test,y_test))
score2=model2.evaluate(x_test,y_test,verbose=0)
print('Test loss:',score2[0])
print('Test accuracy:',score2[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch 1/20
# 469/469 [==============================] - 19s 36ms/step - loss: 0.2464 - accuracy: 0.9259 - val_loss: 0.1129 - val_accuracy: 0.9634
# Epoch 2/20
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1010 - accuracy: 0.9690 - val_loss: 0.0821 - val_accuracy: 0.9741
# Epoch 3/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0716 - accuracy: 0.9770 - val_loss: 0.0693 - val_accuracy: 0.9777
# Epoch 4/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0556 - accuracy: 0.9815 - val_loss: 0.0632 - val_accuracy: 0.9803
# Epoch 5/20
# 469/469 [==============================] - 9s 18ms/step - loss: 0.0446 - accuracy: 0.9863 - val_loss: 0.0676 - val_accuracy: 0.9813
# Epoch 6/20
# 469/469 [==============================] - 10s 21ms/step - loss: 0.0386 - accuracy: 0.9872 - val_loss: 0.0695 - val_accuracy: 0.9807
# Epoch 7/20
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0347 - accuracy: 0.9884 - val_loss: 0.0627 - val_accuracy: 0.9825
# Epoch 8/20
# 469/469 [==============================] - 10s 20ms/step - loss: 0.0308 - accuracy: 0.9902 - val_loss: 0.0665 - val_accuracy: 0.9804
# Epoch 9/20
# 469/469 [==============================] - 8s 18ms/step - loss: 0.0267 - accuracy: 0.9912 - val_loss: 0.0687 - val_accuracy: 0.9823
# Epoch 10/20
# 469/469 [==============================] - 11s 23ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.0776 - val_accuracy: 0.9802
# Test loss: 0.07759741693735123
# Test accuracy: 0.9801999926567078
